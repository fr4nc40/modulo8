# %%
import seaborn as sns
import pandas as pd

# %%
dt = pd.read_csv('sao_paulo.csv',sep=";")

# %%
correlacao =  dt.corr()

# %%
plot = sns.heatmap(correlacao, annot = True, fmt=".1f", linewidths=.6)
plot
# Out:
# <AxesSubplot:>
